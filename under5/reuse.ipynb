# %%
import pandas as pd

# %%
df = pd.read_csv('../../data/processed/edhs/Unimputed_CHM_1.csv')
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Region  Rural_Urban  No_of_Children_under_5  Age_at_1st_Birth  BirthOrder  \
# 0       1            2                       1                23           1
# 1       1            2                       2                16           8
# 2       1            2                       2                16           7
# 3       1            2                       2                15           7
# 4       1            2                       2                15           6
#
#    Prec.BirthInterval  TotalChildren  HighestEducation  SexofChild  childSize  \
# 0                 NaN              1                 1           1        5.0
# 1                28.0              7                 0           1        5.0
# 2                37.0              7                 0           2        3.0
# 3                26.0              5                 0           2        1.0
# 4                29.0              5                 0           1        3.0
#
# ...

# %%
col = list(df.columns)
val = list(df.isna().sum())
zip_iterator = zip(col, val)
missing_values = dict(zip_iterator)

# %%
missing_values
# Out:
# {'Region': 0,
#  'Rural_Urban': 0,
#  'No_of_Children_under_5': 0,
#  'Age_at_1st_Birth': 0,
#  'BirthOrder': 0,
#  'Prec.BirthInterval': 9915,
#  'TotalChildren': 0,
#  'HighestEducation': 0,
#  'SexofChild': 0,
#  'childSize': 5719,
#  'WealthQuantile': 10873,
#  'prev_termin_pregnancy': 5719,
#  'Year': 0,
#  'Toiletfascility': 1323,
#  'HandwashFascility': 9232,
#  'Place_of_delivery': 6389,
#  'Contraceptive_use': 0,
#  'Mediaexposure': 5458,
#  'age': 0,
#  'dead_alive': 0}

# %%
df.head(20).to_csv('./data/sample_edhs.csv')
